# %%
import pandas as pd
import numpy as np
import autoviz
from autoviz import data_cleaning_suggestions

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
# Loading the dataset
df = pd.read_csv('./diabetes_prediction_dataset.csv')

df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history   bmi   \
# 0  Female  80.0        0             1              never     25.19
# 1  Female  54.0        0             0            No Info     27.32
# 2    Male  28.0        0             0              never     27.32
# 3  Female  36.0        0             0            current     23.45
# 4    Male  76.0        1             1            current     20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0      6.6              140              0
# 1      6.6               80              0
# 2      5.7              158              0
# 3      5.0              155              0
# 4      4.8              155              0

# %%
df.describe().T
# Out:
#                        count      mean        std      min     25%     50%   \
# age                  100000.0   41.885856  22.516840   0.08   24.00   43.00
# hypertension         100000.0    0.074850   0.263150   0.00    0.00    0.00
# heart_disease        100000.0    0.039420   0.194593   0.00    0.00    0.00
# bmi                  100000.0   27.320767   6.636783  10.01   23.63   27.32
# HbA1c_level          100000.0    5.527507   1.070672   3.50    4.80    5.80
# blood_glucose_level  100000.0  138.058060  40.708136  80.00  100.00  140.00
# diabetes             100000.0    0.085000   0.278883   0.00    0.00    0.00
#
#                        75%     max
# age                   60.00   80.00
# hypertension           0.00    1.00
# heart_disease          0.00    1.00
# bmi                   29.58   95.69
# HbA1c_level            6.20    9.00
# blood_glucose_level  159.00  300.00
# diabetes               0.00    1.00

# %%
#df['gender'].value_counts()
df.value_counts(['gender', 'smoking_history'])
# Out:
# gender  smoking_history
# Female  never              22869
#         No Info            19700
# Male    No Info            16110
#         never              12223
# Female  current             5058
#         former              4774
# Male    former              4578
#         current             4228
# Female  not current         3913
# Male    not current         2526
# Female  ever                2238
# Male    ever                1765
# Other   not current            8
#         No Info                6
#         never                  3
#         ever                   1
# Name: count, dtype: int64

# %%
# Data cleaning suggestions
data_cleaning_suggestions(df)
# Out:
# There are 3854 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_02137_row0_col0, #T_02137_row0_col2, #T_02137_row0_col3, #T_02137_row0_col4, #T_02137_row0_col5, #T_02137_row1_col0, #T_02137_row1_col2, #T_02137_row1_col3, #T_02137_row1_col4, #T_02137_row1_col5, #T_02137_row2_col0, #T_02137_row2_col2, #T_02137_row2_col3, #T_02137_row2_col4, #T_02137_row2_col5, #T_02137_row3_col0, #T_02137_row3_col2, #T_02137_row3_col3, #T_02137_row3_col4, #T_02137_row3_col5, #T_02137_row4_col0, #T_02137_row4_col2, #T_02137_row4_col3, #T_02137_row4_col4, #T_02137_row4_col5, #T_02137_row5_col0, #T_02137_row5_col2, #T_02137_row5_col3, #T_02137_row5_col4, #T_02137_row5_col5, #T_02137_row6_col0, #T_02137_row6_col2, #T_02137_row6_col3, #T_02137_row6_col4, #T_02137_row6_col5, #T_02137_row7_col0, #T_02137_row7_col2, #T_02137_row7_col3, #T_02137_row7_col4, #T_02137_row7_col5, #T_02137_row8_col0, #T_02137_row8_col2, #T_02137_row8_col3, #T_02137_row8_col4, #T_02137_row8_col5 {
#   font-family: Segoe UI;
# }
# #T_02137_row0_col1, #T_02137_row1_col1, #T_02137_row2_col1, #T_02137_row3_col1, #T_02137_row4_col1, #T_02137_row5_col1, #T_02137_row6_col1, #T_02137_row7_col1, #T_02137_row8_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_02137">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02137_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_02137_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_02137_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_02137_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_02137_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_02137_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02137_level0_row0" class="row_heading level0 row0" >gender</th>
#       <td id="T_02137_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_02137_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_02137_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_02137_row0_col3" class="data row0 col3" ></td>
#       <td id="T_02137_row0_col4" class="data row0 col4" ></td>
#       <td id="T_02137_row0_col5" class="data row0 col5" >1 rare categories: ['Other']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_02137_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_02137_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_02137_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_02137_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_02137_row1_col3" class="data row1 col3" >0.080000</td>
#       <td id="T_02137_row1_col4" class="data row1 col4" >80.000000</td>
#       <td id="T_02137_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_02137_level0_row2" class="row_heading level0 row2" >hypertension</th>
#       <td id="T_02137_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_02137_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_02137_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_02137_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_02137_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_02137_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_02137_level0_row3" class="row_heading level0 row3" >heart_disease</th>
#       <td id="T_02137_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_02137_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_02137_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_02137_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_02137_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_02137_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_02137_level0_row4" class="row_heading level0 row4" >smoking_history</th>
#       <td id="T_02137_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_02137_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_02137_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_02137_row4_col3" class="data row4 col3" ></td>
#       <td id="T_02137_row4_col4" class="data row4 col4" ></td>
#       <td id="T_02137_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_02137_level0_row5" class="row_heading level0 row5" >bmi</th>
#       <td id="T_02137_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_02137_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_02137_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_02137_row5_col3" class="data row5 col3" >10.010000</td>
#       <td id="T_02137_row5_col4" class="data row5 col4" >95.690000</td>
#       <td id="T_02137_row5_col5" class="data row5 col5" >Column has 5354 outliers greater than upper bound (39.55) or lower than lower bound(13.71). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_02137_level0_row6" class="row_heading level0 row6" >HbA1c_level</th>
#       <td id="T_02137_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_02137_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_02137_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_02137_row6_col3" class="data row6 col3" >3.500000</td>
#       <td id="T_02137_row6_col4" class="data row6 col4" >9.000000</td>
#       <td id="T_02137_row6_col5" class="data row6 col5" >Column has 1312 outliers greater than upper bound (8.30) or lower than lower bound(2.70). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_02137_level0_row7" class="row_heading level0 row7" >blood_glucose_level</th>
#       <td id="T_02137_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_02137_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_02137_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_02137_row7_col3" class="data row7 col3" >80.000000</td>
#       <td id="T_02137_row7_col4" class="data row7 col4" >300.000000</td>
#       <td id="T_02137_row7_col5" class="data row7 col5" >Column has 2031 outliers greater than upper bound (247.50) or lower than lower bound(11.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_02137_level0_row8" class="row_heading level0 row8" >diabetes</th>
#       <td id="T_02137_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_02137_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_02137_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_02137_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_02137_row8_col4" class="data row8 col4" >1.000000</td>
#       <td id="T_02137_row8_col5" class="data row8 col5" >No issue</td>
#     </tr>
#   </tbody>
# </table>
#                     Data Type  Missing Values% Unique Values% Minimum Value  \
# gender                 object        0.0              0
# age                   float64        0.0             NA             0.08
# hypertension            int64        0.0              0              0.0
# heart_disease           int64        0.0              0              0.0
# smoking_history        object        0.0              0
# bmi                   float64        0.0             NA            10.01
# HbA1c_level           float64        0.0             NA              3.5
# blood_glucose_level     int64        0.0              0             80.0
# diabetes                int64        0.0              0              0.0
#
#                     Maximum Value  \
# gender
# age                       80.0
# hypertension               1.0
# heart_disease              1.0
# smoking_history
# bmi                      95.69
# HbA1c_level                9.0
# blood_glucose_level      300.0
# diabetes                   1.0
#
#                                                                            DQ Issue
# gender                                             1 rare categories: ['Other']. Group them into a single category or drop the categories.
# age                                                                                                                               No issue
# hypertension                                                                                                                      No issue
# heart_disease                                                                                                                     No issue
# smoking_history                                                                                                                   No issue
# bmi                   Column has 5354 outliers greater than upper bound (39.55) or lower than lower bound(13.71). Cap them or remove them.
# HbA1c_level             Column has 1312 outliers greater than upper bound (8.30) or lower than lower bound(2.70). Cap them or remove them.
# blood_glucose_level  Column has 2031 outliers greater than upper bound (247.50) or lower than lower bound(11.50). Cap them or remove them.
# diabetes                                                                                                                          No issue

# %%
le = LabelEncoder()

list_str = ['gender', 'smoking_history']
for c in list_str:
    df[c] = le.fit_transform(df[c])
    print(dict(zip(le.classes_,range(len(le.classes_)))))
# Out:
# {'Female': 0, 'Male': 1, 'Other': 2}
# {'No Info': 0, 'current': 1, 'ever': 2, 'former': 3, 'never': 4, 'not current': 5}

# %%
X = df.drop('diabetes', axis = 1)
y = df['diabetes']

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.2, random_state = 0)

X.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history   bmi   \
# 0     0    80.0        0             1               4         25.19
# 1     0    54.0        0             0               0         27.32
# 2     1    28.0        0             0               4         27.32
# 3     0    36.0        0             0               1         23.45
# 4     1    76.0        1             1               1         20.14
#
#    HbA1c_level  blood_glucose_level
# 0      6.6              140
# 1      6.6               80
# 2      5.7              158
# 3      5.0              155
# 4      4.8              155

# %%
# scaler = StandardScaler()
# xtrain = scaler.fit_transform(xtrain)
# xtest = scaler.transform(xtest)

# %%
model = Sequential([
    Input(shape=(8,)),
    Dense(32, activation = 'relu', input_shape = (xtrain.shape[1],)),
    Dropout(0.1),
    Dense(32, activation = 'relu'),
    Dropout(0.5),
    Dense(1, activation = 'sigmoid')
])

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,377 (5.38 KB)
#  Trainable params: 1,377 (5.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(xtrain, ytrain, epochs = 5, batch_size = 16, validation_data = (xtest, ytest))
# Out:
# Epoch 1/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.8934 - loss: 0.8589 - val_accuracy: 0.9148 - val_loss: 0.2459
# Epoch 2/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9202 - loss: 0.2538 - val_accuracy: 0.9290 - val_loss: 0.2221
# Epoch 3/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9235 - loss: 0.2356 - val_accuracy: 0.9344 - val_loss: 0.1977
# Epoch 4/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9271 - loss: 0.2075 - val_accuracy: 0.9380 - val_loss: 0.1546
# Epoch 5/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9363 - loss: 0.1775 - val_accuracy: 0.9548 - val_loss: 0.1268

# %%
loss, accuracy = model.evaluate(xtest, ytest)

print(f'Test loss: {loss:.4f}')
print(f'Test accuracy: {accuracy:.4f}')
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9536 - loss: 0.1660
# Test loss: 0.1637
# Test accuracy: 0.9532

# %%
model.save('y.h5')

# %%
import tensorflow as tf
import tensorflowjs as tfjs
model = tf.keras.models.load_model('y.h5')

for layer in model.layers:
    for weight in layer.weights:
        weight.name = '{0}/{1}'.format(layer.name, weight.name)

tfjs.converters.save_keras_model(model, 'web')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 2
#       1 import tensorflow as tf
# ----> 2 import tensorflowjs as tfjs
#       3 model = tf.keras.models.load_model('y.h5')
#       5 for layer in model.layers:
#
# ModuleNotFoundError: No module named 'tensorflowjs'
